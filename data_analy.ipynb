# %%
import preprossesing as pre

# %%
import pandas as pd
df = pd.read_csv('data/train.csv')
df
# Out:
#                           id manufacturer model  year gearbox_type  \
# 0     KLbmH3ej7SqGtgiAeCCSzg            F   F_5  2017    Automatic
# 1     7RXmiuUnmgXpRP2aMvpQvg            I   I_4  2019    Semi-Auto
# 2     djEAH3eEjTNi9kB5tdqyZ2            A   A_1  2019    Automatic
# 3     Zr4BmbgnVvCiu2kzJKnWT2            B   B_6  2019    Semi-Auto
# 4     in2F32L5vcnWJNfmAyKD6U            F   F_5  2014       Manual
# ...                      ...          ...   ...   ...          ...
# 9995  2mAqdD98ivYSFgftAD6ACu            C   C_1  2019       Manual
# 9996  7uA9fabuizSXtpzmBmGAPr            C   C_1  2017       Manual
# 9997  PExTX3ZMN6JkkoTfNnzqnt            I  I_17  2017    Semi-Auto
# 9998  eptnMepHWmURmPYF6RTdrr            B  B_13  2020       Manual
# 9999  KZukBYBP49MwP74ZAxmk89            G   G_0  2019       Manual
#
#       operating_hours fuel_type  registration_fees  efficiency  \
# 0                3620    Petrol                145        67.0
# 1                3393    Petrol                145        29.5
# 2                2671    Petrol                145        51.4
# 3                3633    Petrol                145        30.4
# 4               13085    Petrol                  0        65.7
# ...               ...       ...                ...         ...
# 9995            10637    Petrol                145        47.1
# 9996            60142    Diesel                  0        74.3
# 9997            24353    Petrol                145        53.3
# 9998             1850    Diesel                150        49.6
# 9999             2112    Petrol                145        58.9
#
#       engine_capacity  price
# 0                 1.0   8500
# 1                 3.0  59812
# 2                 1.4  16999
# 3                 2.0  33790
# 4                 1.0   5273
# ...               ...    ...
# 9995              1.5  17298
# 9996              1.6  11490
# 9997              1.6  20352
# 9998              2.0  29998
# 9999              1.0  15495
#
# [10000 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

def get_graph(column):
    x = df[column]
    y = df['price']
    plt.scatter(x, y, marker='.')
    plt.title(column)
    plt.show()

# %%
pre.remove_outliers(df)
pre.standardize(df)
columns = ['year', 'registration_fees', 'operating_hours', 'engine_capacity', 'efficiency', 'manufacturer', 'model', 'gearbox_type', 'fuel_type']


fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for ax, column in zip(axs.flatten(), columns):
    x = df[column]
    y = df['price']
    ax.scatter(x, y, marker='.')
    ax.set_title(column)

plt.tight_layout()
plt.show()


pre.encoder(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pre.remove_outliers(df)
#       2 pre.standardize(df)
#       3 columns = ['year', 'registration_fees', 'operating_hours', 'engine_capacity', 'efficiency', 'manufacturer', 'model', 'gearbox_type', 'fuel_type']
#
# File ~/Library/CloudStorage/OneDrive-HKUSTConnect/Y3F/COMP5212/Project/COMP5212_project/preprossesing.py:57, in remove_outliers(df)
#      55 from sklearn.ensemble import IsolationForest
#      56 clf = IsolationForest(random_state=0).fit(X = df[['operating_hours', 'efficiency', 'year']], y = df['price'])
# ---> 57 outliers = clf.predict(df)
#      58 df = df[outliers == 1]
#      59 return df
#
# File /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/ensemble/_iforest.py:369, in IsolationForest.predict(self, X)
#     352 """
#     353 Predict if a particular sample is an outlier or not.
#     354
#    (...)
#     366     be considered as an inlier according to the fitted model.
#     367 """
#     368 check_is_fitted(self)
# --> 369 decision_func = self.decision_function(X)
#     370 is_inlier = np.ones_like(decision_func, dtype=int)
#     371 is_inlier[decision_func < 0] = -1
#
# File /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/ensemble/_iforest.py:404, in IsolationForest.decision_function(self, X)
#     375 """
#     376 Average anomaly score of X of the base classifiers.
#     377
#    (...)
#     399     positive scores represent inliers.
#     400 """
#     401 # We subtract self.offset_ to make 0 be the threshold value for being
#     402 # an outlier:
# --> 404 return self.score_samples(X) - self.offset_
#
# File /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/ensemble/_iforest.py:431, in IsolationForest.score_samples(self, X)
#     407 """
#     408 Opposite of the anomaly score defined in the original paper.
#     409
#    (...)
#     428     The lower, the more abnormal.
#     429 """
#     430 # Check data
# --> 431 X = self._validate_data(X, accept_sparse="csr", dtype=tree_dtype, reset=False)
#     433 return self._score_samples(X)
#
# File /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - engine_capacity
# - fuel_type
# - gearbox_type
# - id
# - manufacturer
# - ...
