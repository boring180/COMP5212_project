# %%
import preprossesing as pre

# %%
import pandas as pd
df = pd.read_csv('data/train.csv')
df
# Out:
#                           id manufacturer model  year gearbox_type  \
# 0     KLbmH3ej7SqGtgiAeCCSzg            F   F_5  2017    Automatic
# 1     7RXmiuUnmgXpRP2aMvpQvg            I   I_4  2019    Semi-Auto
# 2     djEAH3eEjTNi9kB5tdqyZ2            A   A_1  2019    Automatic
# 3     Zr4BmbgnVvCiu2kzJKnWT2            B   B_6  2019    Semi-Auto
# 4     in2F32L5vcnWJNfmAyKD6U            F   F_5  2014       Manual
# ...                      ...          ...   ...   ...          ...
# 9995  2mAqdD98ivYSFgftAD6ACu            C   C_1  2019       Manual
# 9996  7uA9fabuizSXtpzmBmGAPr            C   C_1  2017       Manual
# 9997  PExTX3ZMN6JkkoTfNnzqnt            I  I_17  2017    Semi-Auto
# 9998  eptnMepHWmURmPYF6RTdrr            B  B_13  2020       Manual
# 9999  KZukBYBP49MwP74ZAxmk89            G   G_0  2019       Manual
#
#       operating_hours fuel_type  registration_fees  efficiency  \
# 0                3620    Petrol                145        67.0
# 1                3393    Petrol                145        29.5
# 2                2671    Petrol                145        51.4
# 3                3633    Petrol                145        30.4
# 4               13085    Petrol                  0        65.7
# ...               ...       ...                ...         ...
# 9995            10637    Petrol                145        47.1
# 9996            60142    Diesel                  0        74.3
# 9997            24353    Petrol                145        53.3
# 9998             1850    Diesel                150        49.6
# 9999             2112    Petrol                145        58.9
#
#       engine_capacity  price
# 0                 1.0   8500
# 1                 3.0  59812
# 2                 1.4  16999
# 3                 2.0  33790
# 4                 1.0   5273
# ...               ...    ...
# 9995              1.5  17298
# 9996              1.6  11490
# 9997              1.6  20352
# 9998              2.0  29998
# 9999              1.0  15495
#
# [10000 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

def get_graph(column):
    x = df[column]
    y = df['price']
    plt.scatter(x, y, marker='.')
    plt.title(column)
    plt.show()

# %%
pre.remove_outliers(df)
pre.standardize(df)
columns = ['year', 'registration_fees', 'operating_hours', 'engine_capacity', 'efficiency', 'manufacturer', 'model', 'gearbox_type', 'fuel_type']


fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for ax, column in zip(axs.flatten(), columns):
    x = df[column]
    y = df['price']
    ax.scatter(x, y, marker='.')
    ax.set_title(column)

plt.tight_layout()
plt.show()


pre.encoder(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/64/cy9kvd894_bfkfb71dsbxt2w0000gn/T/ipykernel_78944/1533220817.py in ?()
#       1 df.drop(columns=['id'], inplace=True, axis=1)
# ----> 2 pre.remove_outliers(df)
#       3 columns = ['year', 'registration_fees', 'operating_hours', 'engine_capacity', 'efficiency', 'manufacturer', 'model', 'gearbox_type', 'fuel_type']
#       4
#       5
#
# ~/Library/CloudStorage/OneDrive-HKUSTConnect/Y3F/COMP5212/Project/COMP5212_project/preprossesing.py in ?(df)
#      54 def remove_outliers(df):
#      55     from sklearn.ensemble import IsolationForest
# ---> 56     clf = IsolationForest(random_state=0).fit(df)
#      57     outliers = clf.predict(df)
#      58     df = df[outliers == 1]
#      59     return df
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1470                 skip_parameter_validation=(
#    1471                     prefer_skip_nested_validation or global_skip_validation
#    1472                 )
#    1473             ):
# -> 1474                 return fit_method(estimator, *args, **kwargs)
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/ensemble/_iforest.py in ?(self, X, y, sample_weight)
#     281         -------
#     282         self : object
#     283             Fitted estimator.
#     284         """
# --> 285         X = self._validate_data(X, accept_sparse=["csc"], dtype=tree_dtype)
#     286         if issparse(X):
#     287             # Pre-sort indices to avoid that each individual tree of the
#     288             # ensemble sorts the indices.
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     629                 out = y
#     630             else:
#     631                 out = X, y
#     632         elif not no_val_X and no_val_y:
# --> 633             out = check_array(X, input_name="X", **check_params)
#     634         elif no_val_X and not no_val_y:
#     635             out = _check_y(y, **check_params)
#     636         else:
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     994                         )
#     995                     array = xp.astype(array, dtype, copy=False)
#     996                 else:
#     997                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 998             except ComplexWarning as complex_warning:
#     999                 raise ValueError(
#    1000                     "Complex data not supported\n{}\n".format(array)
#    1001                 ) from complex_warning
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     517         # Use NumPy API to support order
#     518         if copy is True:
#     519             array = numpy.array(array, order=order, dtype=dtype)
#     520         else:
# --> 521             array = numpy.asarray(array, order=order, dtype=dtype)
#     522
#     523         # At this point array is a NumPy ndarray. We convert it to an array
#     524         # container that is consistent with the input's namespace.
#
# /opt/anaconda3/envs/pytorch2.0/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'F'
